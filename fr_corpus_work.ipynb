# %%
#pip install PyPDF2
# Out:
# Requirement already satisfied: openpyxl in c:\users\eugen\anaconda3\lib\site-packages (3.0.10)
# Requirement already satisfied: et_xmlfile in c:\users\eugen\anaconda3\lib\site-packages (from openpyxl) (1.1.0)

# %%
import os
import pandas as pd
from PyPDF2 import PdfReader
import re

# %%
def delete_specific_files(directory_path, patterns):
    file_count = 0

    for filename in os.listdir(directory_path):
        # Check if the filename contains any of the specified patterns
        if any(pattern in filename for pattern in patterns):
            file_path = os.path.join(directory_path, filename)
            os.remove(file_path)  # Delete the file
            file_count += 1
            print(f"Deleted file: {filename}")

    print(f"Total files deleted: {file_count}")

# Directory path
directory_path = 'C:\\Users\\eugen\\corpus_article_debt\\raw files\\raw docs FR'

# Patterns to search for in filenames
patterns = ["Attachment", "(2)", "(3)", "(4)"]

# Execute the function
delete_specific_files(directory_path, patterns)
# Out:
# Total files deleted: 0

# %%
# Function 1: Extract title, text, and length
def extract_title_text_length(text):
    # Extract Title
    title = text.split('\n')[0]
    body_index = text.find('Body')
    article_text = text[body_index + len('Body'):].strip()
    
    # Try to find the length by looking for any characters after "Length:"
    length_match = re.search(r'Length:\s?(.+)', text)
    
    if length_match:
        length_str = length_match.group(1).strip()  # Extract the entire string and remove leading/trailing spaces
        # Check if the string contains only digits
        if length_str.isdigit():
            length = int(length_str)  # Convert to integer if it contains only digits
        else:
            length = length_str  # Keep as string if it contains other characters
    else:
        length = None

    return title, length

# %%
# Function 2: Extract the date and convert it to the correct date
def extract_date(text):
    # Mapping of French days and months to English
    day_mapping = {
        'Lundi': 'Monday', 'Mardi': 'Tuesday', 'Mercredi': 'Wednesday', 
        'Jeudi': 'Thursday', 'Vendredi': 'Friday', 'Samedi': 'Saturday', 
        'Dimanche': 'Sunday'
    }
    month_mapping = {
        'Janvier': 'January', 'Février': 'February', 'Mars': 'March', 'Avril': 'April',
        'Mai': 'May', 'Juin': 'June', 'Juillet': 'July', 'Août': 'August',
        'Septembre': 'September', 'Octobre': 'October', 'Novembre': 'November', 'Décembre': 'December'
    }

    # Define date pattern in French
    date_pattern = r'(?:Lundi|Mardi|Mercredi|Jeudi|Vendredi|Samedi|Dimanche)?,?\s?\d{1,2} (Janvier|Février|Mars|Avril|Mai|Juin|Juillet|Août|Septembre|Octobre|Novembre|Décembre) \d{4}'
    
    date_match = re.search(date_pattern, text, re.IGNORECASE)
    date = None

    if date_match:
        date_str = date_match.group(0)
        # Replace French days and months with English
        for fr, en in day_mapping.items():
            date_str = re.sub(fr, en, date_str, flags=re.IGNORECASE)
        for fr, en in month_mapping.items():
            date_str = re.sub(fr, en, date_str, flags=re.IGNORECASE)

        # Attempt to parse the date string into a datetime object
        try:
            date = pd.to_datetime(date_str, errors='coerce', dayfirst=True)
            if date is not None and not pd.isnull(date):
                date = date.strftime('%Y-%m-%d')
            else:
                date = date_match.group(0)  # Fallback: Return the original extracted date string
        except ValueError:
            date = date_match.group(0)  # Fallback: Return the original extracted date string

    return date

# %%
# Function 3: Extract the newspaper name
def extract_newspaper_name_from_start(text, newspaper_list, lines_to_check=8):
    newspaper_name = None
    lines = text.split('\n')[:lines_to_check]  # Split the text into lines and take the first few lines
    for line in lines:
        for newspaper in newspaper_list:
            if newspaper.lower() in line.lower():
                newspaper_name = newspaper
                return newspaper_name
    return newspaper_name

# Newspaper list
newspaper_list = [
    'Le Monde',
    'Le Figaro',
    'Libération',
    'La Croix',
    'Le Parisien',
    "L'Humanité",
    'Les Échos',
    'La Tribune',
    'Le Canard Enchaîné',
    "L'Équipe",
    'Le Nouvel Observateur',
    'Le Point',
    "L'Express",
    'Mediapart',
    'Charlie Hebdo',
    'Ouest-France',
    'Le Temps',
    'Le Dauphiné Libéré',
    'La Voix du Nord',
    "L'Aisne Nouvelle",
    'Le Télégramme',
    'La Montagne',
    'La Provence',
    "Le Parisien - Aujourd'hui en France",
    'Courrier International'
]

# %%
#Function 4: Extract text correctly without additional "Load-Date" etc
def extract_text_from_pdf(pdf_path):
    text = ''
    with open(pdf_path, 'rb') as file:
        reader = PdfReader(file)
        for page in reader.pages:
            text += page.extract_text() if page.extract_text() else ''
    return text

start_indicator = "Body"
end_indicator = "Load-Date"

def identify_text_body(text, start_indicator, end_indicator):
    start_index = text.find(start_indicator)
    if start_index != -1:
        start_index += len(start_indicator)  # Move start index to the end of the start_indicator
    else:
        start_index = 0  # Start from the beginning if start_indicator not found
    
    end_index = text.find(end_indicator, start_index) if end_indicator in text and start_index != -1 else len(text)
    
    if start_index != -1 and end_index != -1:
        return text[start_index:end_index].strip()
    else:
        return text[start_index:].strip()  # Return the text from start_indicator to the end if end_indicator is not found

# %%
# Function 5: Identify the language
def identify_language(folder_path):
    """
    Identifies the language based on markers in the folder path.

    Parameters:
    - folder_path (str): The path of the folder which likely contains language markers.

    Returns:
    - str: The identified language ('French', 'German', or 'Unknown').
    """
    if "FR" in folder_path:
        return 'French'
    elif "DE" in folder_path:
        return 'German'
    else:
        return 'Unknown'

# %%
def clean_text(text):
    """Clean text by removing or replacing null bytes and control characters.
    
    If text is None, return an empty string."""
    if text is None:
        return ''
    return ''.join(char for char in text if char.isprintable())

# %%
def compile_and_save_corpus(directory_path, output_xlsx_path):
    file_count = 0  # To keep track of how many files have been processed
    
    # Open the Excel writer outside the loop
    writer = pd.ExcelWriter(output_xlsx_path, engine='openpyxl')
    
    for filename in os.listdir(directory_path):
        if filename.endswith('.pdf'):
            file_path = os.path.join(directory_path, filename)
            print(f"Processing file: {filename}")  # Debugging statement
            
            text = extract_text_from_pdf(file_path)
            title, length = extract_title_text_length(text)
            article_text = identify_text_body(text, 'start_indicator', 'end_indicator')
            date = extract_date(text)
            newspaper_name = extract_newspaper_name_from_start(text, 'newspaper_list', lines_to_check=7)
            language = identify_language(directory_path)
            
            # Apply cleaning to the extracted text data
            title = clean_text(title)
            article_text = clean_text(article_text)
            newspaper_name = clean_text(newspaper_name)
            
            # Create a DataFrame for the current file's data
            corpus_df = pd.DataFrame([{
                'Title': title,
                'Text Body': article_text,
                'Length': length,
                'Date': date,
                'Newspaper Name': newspaper_name,
                'Language': language
            }])
            
            # Write the current DataFrame to Excel file, appending if it's not the first file
            if file_count == 0:
                corpus_df.to_excel(writer, index=False)
            else:
                corpus_df.to_excel(writer, index=False, header=None, startrow=file_count + 1)
            
            file_count += 1
            print(f"File processed: {filename}")  # Debugging statement
    
    # Save and close the Excel writer after all files have been processed
    writer.save()
    writer.close()
    print(f"Total files processed: {file_count}")  # Debugging statement
    print(f"Corpus saved to: {output_xlsx_path}")  # Debugging statement

# %%
# Run the main function
# Run it on French documents
directory_path = 'C:\\Users\\eugen\\corpus_article_debt\\raw files\\raw docs FR'
output_xlsx_path = 'C:\\Users\\eugen\\corpus_article_debt\\corpus_article_debt_FR.xlsx'
compile_and_save_corpus(directory_path, output_xlsx_path)
# Out:
# Processing file: 2375 milliards d'euros_ faut-il avoir peur de l'abyssale dette fran_aise_.pdf
# File processed: 2375 milliards d'euros_ faut-il avoir peur de l'abyssale dette fran_aise_.pdf
# Processing file: 57,4 milliards de dollars _ L'appui de la Banque mondiale aux pays en d_veloppement.pdf
# File processed: 57,4 milliards de dollars _ L'appui de la Banque mondiale aux pays en d_veloppement.pdf
# Processing file: A 63 _ des questions sur l _largissement.pdf
# File processed: A 63 _ des questions sur l _largissement.pdf
# Processing file: A Bruxelles, une r_forme minime du Pacte de stabilit_ budg_taire.pdf
# File processed: A Bruxelles, une r_forme minime du Pacte de stabilit_ budg_taire.pdf
# Processing file: A Djibouti , Macron vante des partenariats _respectueux_.pdf
# File processed: A Djibouti , Macron vante des partenariats _respectueux_.pdf
# Processing file: A Paris, un sommet pour _viter le d_crochage _conomique de l'Afrique.pdf
# File processed: A Paris, un sommet pour _viter le d_crochage _conomique de l'Afrique.pdf
# Processing file: A peine majeurs... et d_j_ trop vaccin_s.pdf
# File processed: A peine majeurs... et d_j_ trop vaccin_s.pdf
# Processing file: A quoi servent les hyper-riches _ Dialogue entre le lib_ral Jean-Marc Daniel et l'_conomiste atterr_.pdf
# File processed: A quoi servent les hyper-riches _ Dialogue entre le lib_ral Jean-Marc Daniel et l'_conomiste atterr_.pdf
# Processing file: A Shanghai pour assainir la finance mondiale.pdf
# File processed: A Shanghai pour assainir la finance mondiale.pdf
# Processing file: ALAIN MINC _Je suis plus _ gauche que vous_.pdf
# File processed: ALAIN MINC _Je suis plus _ gauche que vous_.pdf
# Processing file: Alain Supiot_ _Des urnes au travail, nous assistons _ la s_cession des gens ordinaires_.pdf
# Exception ignored in: <function ZipFile.__del__ at 0x00000238F8E7C430>
# Traceback (most recent call last):
#   File "C:\Users\eugen\anaconda3\lib\zipfile.py", line 1816, in __del__
#     self.close()
#   File "C:\Users\eugen\anaconda3\lib\zipfile.py", line 1833, in close
#     self.fp.seek(self.start_dir)
# ValueError: seek of closed file
# File processed: Alain Supiot_ _Des urnes au travail, nous assistons _ la s_cession des gens ordinaires_.pdf
# Processing file: Alerte _ la hausse des taux.pdf
# File processed: Alerte _ la hausse des taux.pdf
# Processing file: Alexandre Farnoux _ _ En Gr_ce, il faudrait un plan Marshall des ruines _.pdf
# File processed: Alexandre Farnoux _ _ En Gr_ce, il faudrait un plan Marshall des ruines _.pdf
# Processing file: Allemagne _ _quation budg_taire complexe pour le nouveau gouvernement.pdf
# File processed: Allemagne _ _quation budg_taire complexe pour le nouveau gouvernement.pdf
# Processing file: Allemagne_ Scholz veut transformer l'_conomie comme jamais depuis 100 ans.pdf
# File processed: Allemagne_ Scholz veut transformer l'_conomie comme jamais depuis 100 ans.pdf
# Processing file: ANALYSE L'agenda europ_en encalmin_ par les rat_s du moteur allemand.pdf
# File processed: ANALYSE L'agenda europ_en encalmin_ par les rat_s du moteur allemand.pdf
# Processing file: ANALYSE Non, l'Allemagne n'est pas l'homme malade de l'Europe.pdf
# File processed: ANALYSE Non, l'Allemagne n'est pas l'homme malade de l'Europe.pdf
# Processing file: ANALYSE _ Washington, l'inflation redevient l'ennemi.pdf
# File processed: ANALYSE _ Washington, l'inflation redevient l'ennemi.pdf
# Processing file: Anne de Guign__ _In_galit_s, la guerre des g_n_rations n'a pas lieu d'_tre_.pdf
# File processed: Anne de Guign__ _In_galit_s, la guerre des g_n_rations n'a pas lieu d'_tre_.pdf
# Processing file: Anne de Guign__ _La lutte pour le climat n'est pas une lutte des classes_.pdf
# File processed: Anne de Guign__ _La lutte pour le climat n'est pas une lutte des classes_.pdf
# Processing file: Annuler la dette fran_aise _ _Ce miracle mon_taire n'est pas une option_ pourfend la Banque de Franc.pdf
# File processed: Annuler la dette fran_aise _ _Ce miracle mon_taire n'est pas une option_ pourfend la Banque de Franc.pdf
# Processing file: Annuler la dette, les cl_s du d_bat Partisans et adversaires d un abandon des dettes publiques d_ten.pdf
# File processed: Annuler la dette, les cl_s du d_bat Partisans et adversaires d un abandon des dettes publiques d_ten.pdf
# Processing file: Anticipation et ambition _ pourquoi le nord et le sud ne pourront plus y _chapper.pdf
# File processed: Anticipation et ambition _ pourquoi le nord et le sud ne pourront plus y _chapper.pdf
# Processing file: Apr_s l'envol_e de la dette en 2020, la ques tion des modalit_s de son remboursement refait surface.pdf
# File processed: Apr_s l'envol_e de la dette en 2020, la ques tion des modalit_s de son remboursement refait surface.pdf
# Processing file: Apr_s la fin de l'euro _ une vraie politique industrielle fran_aise _.pdf
# File processed: Apr_s la fin de l'euro _ une vraie politique industrielle fran_aise _.pdf
# Processing file: Apr_s le _greenwashing_, voici venue l'heure du _greenbashing_.pdf
# File processed: Apr_s le _greenwashing_, voici venue l'heure du _greenbashing_.pdf
# Processing file: Arnaud Montebourg _ _ Mon combat, c'est la revalorisation de la France _.pdf
# File processed: Arnaud Montebourg _ _ Mon combat, c'est la revalorisation de la France _.pdf
# Processing file: Attac va mobiliser contre la ratification du trait_ budg_taire europ_en.pdf
# File processed: Attac va mobiliser contre la ratification du trait_ budg_taire europ_en.pdf
# Processing file: Au coeur des Tea Party.pdf
# File processed: Au coeur des Tea Party.pdf
# Processing file: Au Conseil de Paris, l'opposition annonce qu'elle ne participera pas au d_bat budg_taire.pdf
# File processed: Au Conseil de Paris, l'opposition annonce qu'elle ne participera pas au d_bat budg_taire.pdf
# Processing file: Au-del_ de l'urgence, un plan de relance pour pr_parer la France de 2030.pdf
# File processed: Au-del_ de l'urgence, un plan de relance pour pr_parer la France de 2030.pdf
# Processing file: Australie _ budget exc_dentaire et cadeaux fiscaux avant les _lections.pdf
# File processed: Australie _ budget exc_dentaire et cadeaux fiscaux avant les _lections.pdf
# Processing file: Auteurs _trangers _ le retour en force des Italiens.pdf
# File processed: Auteurs _trangers _ le retour en force des Italiens.pdf
# Processing file: Aux Seychelles , pr_server un paradis du tourisme de masse.pdf
# File processed: Aux Seychelles , pr_server un paradis du tourisme de masse.pdf
# Processing file: Avant une possible d_gradation de la note de la France , Bruno Le Maire promet d'_tre _ intraitable.pdf
# File processed: Avant une possible d_gradation de la note de la France , Bruno Le Maire promet d'_tre _ intraitable.pdf
# Processing file: Avec la croissance, le d_bat sur l'aust_rit_ divise de nouveau l'UE.pdf
# File processed: Avec la croissance, le d_bat sur l'aust_rit_ divise de nouveau l'UE.pdf
# Processing file: Avec la reprise, le d_bat sur l'aust_rit_ fissure l'Europe.pdf
# File processed: Avec la reprise, le d_bat sur l'aust_rit_ fissure l'Europe.pdf
# Processing file: Avec son obligation souveraine verte, la France _ la pointe de la finance durable.pdf
# File processed: Avec son obligation souveraine verte, la France _ la pointe de la finance durable.pdf
# Processing file: Avertissement _ Si on ne fait rien, l'explosion de la dette va paralyser l'action publique _.pdf
# File processed: Avertissement _ Si on ne fait rien, l'explosion de la dette va paralyser l'action publique _.pdf
# Processing file: A_roports et avenir.pdf
# File processed: A_roports et avenir.pdf
# Processing file: Baisser les imp_ts, construire un mur, _mettre KO_ Daech _ voici le programme de Donald Trump.pdf
# File processed: Baisser les imp_ts, construire un mur, _mettre KO_ Daech _ voici le programme de Donald Trump.pdf
# Processing file: Baisses d'imp_t diff_r_es, recettes cibl_es_ vers un budget 2024 prudent.pdf
# File processed: Baisses d'imp_t diff_r_es, recettes cibl_es_ vers un budget 2024 prudent.pdf
# Processing file: Baisses d'imp_ts et mesures d'_conomie au menu du budget 2019.pdf
# File processed: Baisses d'imp_ts et mesures d'_conomie au menu du budget 2019.pdf
# Processing file: Banques_ vers une crise financi_re_.pdf
# File processed: Banques_ vers une crise financi_re_.pdf
# Processing file: Barom_tre _ des Fran_ais sombres mais lucides, des entreprises sous pression sur les salaires.pdf
# File processed: Barom_tre _ des Fran_ais sombres mais lucides, des entreprises sous pression sur les salaires.pdf
# Processing file: Bataille rang_e au pied du _ mur de la dette _ Pour faire face au choc du coronavirus, les _tats doi.pdf
# File processed: Bataille rang_e au pied du _ mur de la dette _ Pour faire face au choc du coronavirus, les _tats doi.pdf
# Processing file: Baverez _ pourquoi ce n'est pas le moment de dormir.pdf
# File processed: Baverez _ pourquoi ce n'est pas le moment de dormir.pdf
# Processing file: Bercy donne un tour de vis suppl_mentaire au budget.pdf
# File processed: Bercy donne un tour de vis suppl_mentaire au budget.pdf
# Processing file: Bercy pr_sente ses pistes pour contenir le budget de la France.pdf
# File processed: Bercy pr_sente ses pistes pour contenir le budget de la France.pdf
# Processing file: Berlin envisage un _budget parall_le_ pour emprunter plus.pdf
# File processed: Berlin envisage un _budget parall_le_ pour emprunter plus.pdf
# Processing file: Bertille Bayart _ _Le cercle des promesses disparues_.pdf
# File processed: Bertille Bayart _ _Le cercle des promesses disparues_.pdf
# Processing file: Bertille Bayart_ _Comment garder le moral en temps de crise_.pdf
# File processed: Bertille Bayart_ _Comment garder le moral en temps de crise_.pdf
# Processing file: Bertille Bayart_ _Nos chers amis allemands_.pdf
# File processed: Bertille Bayart_ _Nos chers amis allemands_.pdf
# Processing file: Biden maintient finalement Powell _ la t_te de la Fed.pdf
# File processed: Biden maintient finalement Powell _ la t_te de la Fed.pdf
# Processing file: Biden, l'homme du consensus.pdf
# File processed: Biden, l'homme du consensus.pdf
# Processing file: BLOC NOTES JACQUES-OLIVIER MARTIN _ @JOCJOM Vingt ans, le plus bel _ge de la Chine.pdf
# File processed: BLOC NOTES JACQUES-OLIVIER MARTIN _ @JOCJOM Vingt ans, le plus bel _ge de la Chine.pdf
# Processing file: BLOC NOTES JACQUES-OLIVIER MARTIN _@JOCJOM Les arbres, nouvelle mode verte.pdf
# File processed: BLOC NOTES JACQUES-OLIVIER MARTIN _@JOCJOM Les arbres, nouvelle mode verte.pdf
# Processing file: Bruno Le Maire appelle les LR _ la responsabilit_ sur la loi de programmation des finances publiques.pdf
# File processed: Bruno Le Maire appelle les LR _ la responsabilit_ sur la loi de programmation des finances publiques.pdf
# Processing file: Bruno Le Maire en Haute-Savoie jeudi pour sa rentr_e.pdf
# File processed: Bruno Le Maire en Haute-Savoie jeudi pour sa rentr_e.pdf
# Processing file: Bruno Le Maire et Olaf Scholz _  _ Pour la premi_re fois, l'Europe agit unie _.pdf
# File processed: Bruno Le Maire et Olaf Scholz _  _ Pour la premi_re fois, l'Europe agit unie _.pdf
# Processing file: Bruno Le Maire _ _ La France ne se r_duit pas _ son _tat _.pdf
# File processed: Bruno Le Maire _ _ La France ne se r_duit pas _ son _tat _.pdf
# Processing file: Bruno Le Maire _ _ La politique a besoin de r_sultats _.pdf
# File processed: Bruno Le Maire _ _ La politique a besoin de r_sultats _.pdf
# Processing file: Bruno Le Maire _ _ Le capitalisme est dans une impasse _.pdf
# File processed: Bruno Le Maire _ _ Le capitalisme est dans une impasse _.pdf
# Processing file: Bruxelles envisage la fin de la c_l_bre r_gle des 3% explication La Commission europ_enne a relanc_.pdf
# File processed: Bruxelles envisage la fin de la c_l_bre r_gle des 3% explication La Commission europ_enne a relanc_.pdf
# Processing file: Bruxelles s'inqui_te de la dette croissante de la France.pdf
# File processed: Bruxelles s'inqui_te de la dette croissante de la France.pdf
# Processing file: Br_sil_ Trump esp_re que Bolsonaro sera un alli_ de poids sur la sc_ne internationale.pdf
# File processed: Br_sil_ Trump esp_re que Bolsonaro sera un alli_ de poids sur la sc_ne internationale.pdf
# Processing file: Budget 2013 - Conseil des ministres du 28 septembre 2012.pdf
# File processed: Budget 2013 - Conseil des ministres du 28 septembre 2012.pdf
# Processing file: Budget 2019 _ l'ex_cutif promet des baisses d'imp_ts malgr_ la croissance en berne.pdf
# File processed: Budget 2019 _ l'ex_cutif promet des baisses d'imp_ts malgr_ la croissance en berne.pdf
# Processing file: Budget 2020_ des baisses d'imp_ts au programme de l'Assembl_e.pdf
# File processed: Budget 2020_ des baisses d'imp_ts au programme de l'Assembl_e.pdf
# Processing file: Budget 2021_ la facture (sal_e) de la relance.pdf
# File processed: Budget 2021_ la facture (sal_e) de la relance.pdf
# Processing file: Budget 2021_ les chiffres cl_s du projet du gouvernement.pdf
# File processed: Budget 2021_ les chiffres cl_s du projet du gouvernement.pdf
# Processing file: Budget 2022_ Le gouvernement d_fend sa _responsabilit__, critique les oppositions.pdf
# File processed: Budget 2022_ Le gouvernement d_fend sa _responsabilit__, critique les oppositions.pdf
# Processing file: Budget 2024 _ Bruno Le Maire loue la sinc_rit_ des projections de croissance, jug_es trop optimistes.pdf
# File processed: Budget 2024 _ Bruno Le Maire loue la sinc_rit_ des projections de croissance, jug_es trop optimistes.pdf
# Processing file: Budget 2024 _ l'inflation et la dette entravent l'_tat.pdf
# File processed: Budget 2024 _ l'inflation et la dette entravent l'_tat.pdf
# Processing file: Budget 2024 _ le gouvernement d_voile sa copie pour maintenir la croissance de l _conomie.pdf
# File processed: Budget 2024 _ le gouvernement d_voile sa copie pour maintenir la croissance de l _conomie.pdf
# Processing file: Budget 2024 _ pas de hausse d'imp_ts, dit Elisabeth Borne, mais peut-_tre une augmentation des franc.pdf
# File processed: Budget 2024 _ pas de hausse d'imp_ts, dit Elisabeth Borne, mais peut-_tre une augmentation des franc.pdf
# Processing file: Budget 2024 _ volontariste sur la transition _cologique, prudent pour le reste.pdf
# File processed: Budget 2024 _ volontariste sur la transition _cologique, prudent pour le reste.pdf
# Processing file: Budget 2024_ l'_tat d_taille ses pistes d'_conomies.pdf
# File processed: Budget 2024_ l'_tat d_taille ses pistes d'_conomies.pdf
# Processing file: Budget 2024_ le Haut Conseil des finances publiques bien plus prudent que l'ex_cutif.pdf
# File processed: Budget 2024_ le Haut Conseil des finances publiques bien plus prudent que l'ex_cutif.pdf
# Processing file: Budget 2024_ le Haut Conseil des finances publiques moins _optimiste_ que le gouvernement sur la cro.pdf
# File processed: Budget 2024_ le Haut Conseil des finances publiques moins _optimiste_ que le gouvernement sur la cro.pdf
# Processing file: Budget et pouvoir d'achat _ la troisi_me, c'est la bonne _.pdf
# File processed: Budget et pouvoir d'achat _ la troisi_me, c'est la bonne _.pdf
# Processing file: Budget _ la Cour des comptes pousse _ la fin du _ quoi qu'il en co_te _ pour 2023.pdf
# File processed: Budget _ la Cour des comptes pousse _ la fin du _ quoi qu'il en co_te _ pour 2023.pdf
# Processing file: Budget _ la surench_re des d_put_s face _ la hausse des prix de l'_nergie.pdf
# File processed: Budget _ la surench_re des d_put_s face _ la hausse des prix de l'_nergie.pdf
# Processing file: Budget _ le bras de fer se durcit entre Bercy et le patronat sur les imp_ts de production.pdf
# File processed: Budget _ le bras de fer se durcit entre Bercy et le patronat sur les imp_ts de production.pdf
# Processing file: Budget _ le gouvernement r_vise _ la baisse ses pr_visions de croissance pour 2024.pdf
# File processed: Budget _ le gouvernement r_vise _ la baisse ses pr_visions de croissance pour 2024.pdf
# Processing file: Budget _ le gouvernement veut inverser la courbe de la d_pense publique.pdf
# File processed: Budget _ le gouvernement veut inverser la courbe de la d_pense publique.pdf
# Processing file: Budget _ Les assises des finances publiques, pour quoi faire _.pdf
# File processed: Budget _ Les assises des finances publiques, pour quoi faire _.pdf
# Processing file: Budget_ Cazenave salue un __change constructif_ avec l'opposition, nouvelle r_union dans 15 jours.pdf
# File processed: Budget_ Cazenave salue un __change constructif_ avec l'opposition, nouvelle r_union dans 15 jours.pdf
# Processing file: Budget_ la surench_re des d_put_s face _ la hausse des prix de l'_nergie.pdf
# File processed: Budget_ la surench_re des d_put_s face _ la hausse des prix de l'_nergie.pdf
# Processing file: Budget__ Bercy veut serrer la ceinture.pdf
# File processed: Budget__ Bercy veut serrer la ceinture.pdf
# Processing file: C'est qui, Bercy_ _ la rencontre des argentiers de la R_publique Au minist_re de l'_conomie et des f.pdf
# File processed: C'est qui, Bercy_ _ la rencontre des argentiers de la R_publique Au minist_re de l'_conomie et des f.pdf
# Processing file: CAC40_ termine en vert, avec le soutien de Wall Street.pdf
# File processed: CAC40_ termine en vert, avec le soutien de Wall Street.pdf
# Processing file: Campagne de Brousse _ _ un but ni de droite, ni de gauche, en plein centre _ !.pdf
# File processed: Campagne de Brousse _ _ un but ni de droite, ni de gauche, en plein centre _ !.pdf
# Processing file: Carlos Lopes « Le cercle vicieux de la dette ouvrira la voie aux populismes et au terrorisme en Afrique ».pdf
# File processed: Carlos Lopes « Le cercle vicieux de la dette ouvrira la voie aux populismes et au terrorisme en Afrique ».pdf
# Processing file: Ce Fran_ais p_se 1 800 milliards de dollars.pdf
# File processed: Ce Fran_ais p_se 1 800 milliards de dollars.pdf
# Processing file: Ce n'_tait pas mieux avant... mais pense-t-on aux difficult_s sp_cifiques des jeunes _.pdf
# File processed: Ce n'_tait pas mieux avant... mais pense-t-on aux difficult_s sp_cifiques des jeunes _.pdf
# Processing file: Ce pays o_ l'on m_prise le travail.pdf
# File processed: Ce pays o_ l'on m_prise le travail.pdf
# Processing file: Ce qu'Emmanuel Macron n'a pas os_ _crire.pdf
# File processed: Ce qu'Emmanuel Macron n'a pas os_ _crire.pdf
# Processing file: Ce qu'il faut changer_ les le_ons de la pand_mie par Michel Onfray, Fr_d_ric Saldman, Nicolas Bavere.pdf
# File processed: Ce qu'il faut changer_ les le_ons de la pand_mie par Michel Onfray, Fr_d_ric Saldman, Nicolas Bavere.pdf
# Processing file: Ce qu'il faut retenir du projet de loi de finances 2018.pdf
# File processed: Ce qu'il faut retenir du projet de loi de finances 2018.pdf
# Processing file: Ce qu'ils font avec notre argent.pdf
# File processed: Ce qu'ils font avec notre argent.pdf
# Processing file: Ce que disent les _ditorialistes.pdf
# File processed: Ce que disent les _ditorialistes.pdf
# Processing file: Ce que l'ann_e 2011 nous r_serve.pdf
# File processed: Ce que l'ann_e 2011 nous r_serve.pdf
# Processing file: Ce que l'on met sous le tapis.pdf
# File processed: Ce que l'on met sous le tapis.pdf
# Processing file: Ce que le syst_me financier peut faire pour le climat.pdf
# File processed: Ce que le syst_me financier peut faire pour le climat.pdf
# Processing file: Ce que nous enseignent les crises du pass_.pdf
# File processed: Ce que nous enseignent les crises du pass_.pdf
# Processing file: Ce rapport au vitriol de la Cour des comptes sur le Grand Paris.pdf
# File processed: Ce rapport au vitriol de la Cour des comptes sur le Grand Paris.pdf
# Processing file: Cessons de creuser le trou de la dette publique.pdf
# File processed: Cessons de creuser le trou de la dette publique.pdf
# Processing file: Changement climatique _ Le Secr_taire g_n_ral de l'OCDE salue les appels lanc_s en faveur de nouvell.pdf
# File processed: Changement climatique _ Le Secr_taire g_n_ral de l'OCDE salue les appels lanc_s en faveur de nouvell.pdf
# Processing file: Christian Lindner, le grand argentier, justifie les volte-face de l'Allemagne.pdf
# File processed: Christian Lindner, le grand argentier, justifie les volte-face de l'Allemagne.pdf
# Processing file: CHRONIQUE Le baby krach.pdf
# File processed: CHRONIQUE Le baby krach.pdf
# Processing file: Cinq ans apr_s, _ Jojo le gilet jaune _ passe _ l'_lectrique.pdf
# File processed: Cinq ans apr_s, _ Jojo le gilet jaune _ passe _ l'_lectrique.pdf
# Processing file: Cinq choses _ savoir sur le plan de relance europ_en.pdf
# File processed: Cinq choses _ savoir sur le plan de relance europ_en.pdf
# Processing file: CLIMAT Pour les plus riches, l'_cot logique s'impose.pdf
# File processed: CLIMAT Pour les plus riches, l'_cot logique s'impose.pdf
# Processing file: Climat _ d_carboner l'_conomie fran_aise, un lourd fardeau pour les finances publiques, selon un rap.pdf
# File processed: Climat _ d_carboner l'_conomie fran_aise, un lourd fardeau pour les finances publiques, selon un rap.pdf
# Processing file: Climat _ qu attendre du _Sommet Biden_ de jeudi _ Washington _.pdf
# File processed: Climat _ qu attendre du _Sommet Biden_ de jeudi _ Washington _.pdf
# Processing file: Climat, guerre, pand_mie _ le FMI lance un fonds de 45 milliards d'euros pour les pays _vuln_rables_.pdf
# File processed: Climat, guerre, pand_mie _ le FMI lance un fonds de 45 milliards d'euros pour les pays _vuln_rables_.pdf
# Processing file: Climat, retraites, successions _ les propositions choc du rapport Blanchard-Tirole.pdf
# File processed: Climat, retraites, successions _ les propositions choc du rapport Blanchard-Tirole.pdf
# Processing file: Climat_ la Convention citoyenne se penche sur les blocages et r_sistances.pdf
# File processed: Climat_ la Convention citoyenne se penche sur les blocages et r_sistances.pdf
# Processing file: Climat_ le nouveau plan de la France pour r_duire plus fortement ses _missions carbone d'ici 2030.pdf
# File processed: Climat_ le nouveau plan de la France pour r_duire plus fortement ses _missions carbone d'ici 2030.pdf
# Processing file: Comit_ mon_taire et financier international.pdf
# File processed: Comit_ mon_taire et financier international.pdf
# Processing file: Comment endiguer la crise de la d_mocratie _.pdf
# File processed: Comment endiguer la crise de la d_mocratie _.pdf
# Processing file: Comment la Nupes peut-elle r_ussir face au pouvoir de l'argent_.pdf
# File processed: Comment la Nupes peut-elle r_ussir face au pouvoir de l'argent_.pdf
# Processing file: Comment le Portugal est devenu le bon _l_ve de l Union europ_enne.pdf
# File processed: Comment le Portugal est devenu le bon _l_ve de l Union europ_enne.pdf
# Processing file: Comment red_marrer l'_conomie _ 10 questions pour comprendre une crise sans pr_c_dent.pdf
# File processed: Comment red_marrer l'_conomie _ 10 questions pour comprendre une crise sans pr_c_dent.pdf
# Processing file: Communiqu_ des chefs d'_tat et de gouvernement du G20.pdf
# File processed: Communiqu_ des chefs d'_tat et de gouvernement du G20.pdf
# Processing file: Comp_titivit_, une guerre de retard.pdf
# File processed: Comp_titivit_, une guerre de retard.pdf
# Processing file: Conf_rence sociale, r_f_rendum sur l'immigration _ Val_rie P_cresse pr_sente son programme des _100.pdf
# File processed: Conf_rence sociale, r_f_rendum sur l'immigration _ Val_rie P_cresse pr_sente son programme des _100.pdf
# Processing file: Construire l'avenir ensemble.pdf
# File processed: Construire l'avenir ensemble.pdf
# Processing file: Construire une _conomie mondiale plus r_siliente et plus inclusive (discours Christine Lagarde).pdf
# File processed: Construire une _conomie mondiale plus r_siliente et plus inclusive (discours Christine Lagarde).pdf
# Processing file: CONTRE EBOLA, L'ALTRUISME RATIONNEL.pdf
# File processed: CONTRE EBOLA, L'ALTRUISME RATIONNEL.pdf
# Processing file: COP21 _ le principal obstacle est le co_t de la dette dans les pays en d_veloppement.pdf
# File processed: COP21 _ le principal obstacle est le co_t de la dette dans les pays en d_veloppement.pdf
# Processing file: COP23 _ les green bonds _ un record de 100 milliards de dollars.pdf
# File processed: COP23 _ les green bonds _ un record de 100 milliards de dollars.pdf
# Processing file: Coronavirus _ les informations essentielles du jeudi 30 avril.pdf
# File processed: Coronavirus _ les informations essentielles du jeudi 30 avril.pdf
# Processing file: Coronavirus _ les jeunes se vivent comme la g_n_ration sacrifi_e de la crise.pdf
# File processed: Coronavirus _ les jeunes se vivent comme la g_n_ration sacrifi_e de la crise.pdf
# Processing file: Coronavirus « Gérer l’urgence et préparer l’avenir ».pdf
# File processed: Coronavirus « Gérer l’urgence et préparer l’avenir ».pdf
# Processing file: Courage, jeunes de France !.pdf
# File processed: Courage, jeunes de France !.pdf
# Processing file: Crise europ_enne et TSCG _ d_claration et motion du Conseil F_d_ral d'EELV.pdf
# File processed: Crise europ_enne et TSCG _ d_claration et motion du Conseil F_d_ral d'EELV.pdf
# Processing file: Crise financi_re ou crise politique _.pdf
# File processed: Crise financi_re ou crise politique _.pdf
# Processing file: CRISE _NERG_TIQUE Entre Paris et Berlin, Rhin ne va plus.pdf
# File processed: CRISE _NERG_TIQUE Entre Paris et Berlin, Rhin ne va plus.pdf
# Processing file: Critiqu_ pour son climatoscepticisme, le pr_sident de la Banque mondiale d_missionne.pdf
# File processed: Critiqu_ pour son climatoscepticisme, le pr_sident de la Banque mondiale d_missionne.pdf
# Processing file: Croissance ralentie, d_ficit, baisse d'imp_t, fonction publique... les 4 chiffres cl_s du projet de.pdf
# File processed: Croissance ralentie, d_ficit, baisse d'imp_t, fonction publique... les 4 chiffres cl_s du projet de.pdf
# Processing file: Croissance, emploi, dette _ _ quoi ressemblera la France en 2025 _.pdf
# File processed: Croissance, emploi, dette _ _ quoi ressemblera la France en 2025 _.pdf
# Processing file: Croissance_ l'UE maintient ses pr_visions mais s'inqui_te du Coronavirus.pdf
# File processed: Croissance_ l'UE maintient ses pr_visions mais s'inqui_te du Coronavirus.pdf
# Processing file: Dans cette r_gion, la comp_tition des puissances s'acc_l_re.pdf
# File processed: Dans cette r_gion, la comp_tition des puissances s'acc_l_re.pdf
# Processing file: DANS LA M_L_E - Faut-il cr_er une alternative _ verte _ au PIB _ OUI_ _ L'INDICATEUR ACTUELN'EST PAS.pdf
# File processed: DANS LA M_L_E - Faut-il cr_er une alternative _ verte _ au PIB _ OUI_ _ L'INDICATEUR ACTUELN'EST PAS.pdf
# Processing file: Dans la zone euro, l’annulation des dettes publiques est une impasse politique.pdf
# File processed: Dans la zone euro, l’annulation des dettes publiques est une impasse politique.pdf
# Processing file: David Lisnard_ _La capitalisation, pour en finir avec le sado-r_formisme des retraites_.pdf
# File processed: David Lisnard_ _La capitalisation, pour en finir avec le sado-r_formisme des retraites_.pdf
# Processing file: David Malpass, pr_sident de la Banque mondiale, annonce sa d_mission prochaine.pdf
# File processed: David Malpass, pr_sident de la Banque mondiale, annonce sa d_mission prochaine.pdf
# Processing file: David Malpass, pr_sident du Groupe de la Banque mondiale Universit_ McGill, Montr_al, Qu_bec , Canad.pdf
# File processed: David Malpass, pr_sident du Groupe de la Banque mondiale Universit_ McGill, Montr_al, Qu_bec , Canad.pdf
# Processing file: David Malpass, quatre ans _ la Banque mondiale marqu_s par les critiques sur le climat.pdf
# File processed: David Malpass, quatre ans _ la Banque mondiale marqu_s par les critiques sur le climat.pdf
# Processing file: De la corruption de la d_mocratie en Am_rique.pdf
# File processed: De la corruption de la d_mocratie en Am_rique.pdf
# Processing file: De Louis XIV _ Macron, histoire d'une addiction fran_aise.pdf
# File processed: De Louis XIV _ Macron, histoire d'une addiction fran_aise.pdf
# Processing file: Des associations d'_lus s'inqui_tent de la baisse des financements pour les collectivit_s.pdf
# File processed: Des associations d'_lus s'inqui_tent de la baisse des financements pour les collectivit_s.pdf
# Processing file: Des milliards et des ardoises pour le futur.pdf
# File processed: Des milliards et des ardoises pour le futur.pdf
# Processing file: Des propositions chiffr_es, m ais pastrop quand m_me.pdf
# File processed: Des propositions chiffr_es, m ais pastrop quand m_me.pdf
# Processing file: Des voeux h_mipl_giques.pdf
# File processed: Des voeux h_mipl_giques.pdf
# Processing file: Des _conomistes conseillant Matignon d_voilent leur plan de relance de 50 milliards.pdf
# File processed: Des _conomistes conseillant Matignon d_voilent leur plan de relance de 50 milliards.pdf
# Processing file: Des _conomistes d_voilent leur plan de relance de 50 milliards.pdf
# File processed: Des _conomistes d_voilent leur plan de relance de 50 milliards.pdf
# Processing file: Des _id_es neuves_ face au mur de la dette L'impact de la crise sanitaire sur les dettes publiques n.pdf
# File processed: Des _id_es neuves_ face au mur de la dette L'impact de la crise sanitaire sur les dettes publiques n.pdf
# Processing file: Dette de la BCE « Aucun traité n’interdit à un créancier de renoncer à ses créances ».pdf
# File processed: Dette de la BCE « Aucun traité n’interdit à un créancier de renoncer à ses créances ».pdf
# Processing file: Dette de la BCE « Les partisans de l’annulation mesurent-ils à quel point ils manient une matière inflammable ».pdf
# File processed: Dette de la BCE « Les partisans de l’annulation mesurent-ils à quel point ils manient une matière inflammable ».pdf
# Processing file: Dette du Tchad_ le FMI exhorte les cr_anciers priv_s _ s'engager _sans plus tarder_.pdf
# File processed: Dette du Tchad_ le FMI exhorte les cr_anciers priv_s _ s'engager _sans plus tarder_.pdf
# Processing file: Dette et d_ficit _ comment le gouvernement veut _ refroidir la d_pense publique _.pdf
# File processed: Dette et d_ficit _ comment le gouvernement veut _ refroidir la d_pense publique _.pdf
# Processing file: Dette européenne « Comme un marronnier, la tentation du défaut de paiement volontaire revient régulièrement ».pdf
# File processed: Dette européenne « Comme un marronnier, la tentation du défaut de paiement volontaire revient régulièrement ».pdf
# Processing file: Dette facile, taxation des riches, d_croissance... _ la foire aux boniments.pdf
# File processed: Dette facile, taxation des riches, d_croissance... _ la foire aux boniments.pdf
# Processing file: Dette ou souverainet_ _ il faut choisir !.pdf
# File processed: Dette ou souverainet_ _ il faut choisir !.pdf
# Processing file: Dette publique « Cantonnement ou annulation, un débat sans issue ».pdf
# File processed: Dette publique « Cantonnement ou annulation, un débat sans issue ».pdf
# Processing file: Dette publique_ la bonne et la mauvaise.pdf
# File processed: Dette publique_ la bonne et la mauvaise.pdf
# Processing file: Dette publique_ le casse-t_te de la r_forme des r_gles europ_ennes.pdf
# File processed: Dette publique_ le casse-t_te de la r_forme des r_gles europ_ennes.pdf
# Processing file: Dette publique_ les _conomistes divis_s sur la gravit_ de la d_rive des comptes.pdf
# File processed: Dette publique_ les _conomistes divis_s sur la gravit_ de la d_rive des comptes.pdf
# Processing file: Dette publique_ qui va payer la note du _quoi qu'il en co_te__.pdf
# File processed: Dette publique_ qui va payer la note du _quoi qu'il en co_te__.pdf
# Processing file: Dette publique__ reprenons en main les politiques mon_taire et fiscale.pdf
# File processed: Dette publique__ reprenons en main les politiques mon_taire et fiscale.pdf
# Processing file: Dette _ la France _ la peine et _ la tra_ne.pdf
# File processed: Dette _ la France _ la peine et _ la tra_ne.pdf
# Processing file: Dette _ la peur d'une mauvaise note.pdf
# File processed: Dette _ la peur d'une mauvaise note.pdf
# Processing file: Dette « éternelle » et Covid-19 « Il paraît que cela fonctionne, même si l’on n’y croit pas ».pdf
# File processed: Dette « éternelle » et Covid-19 « Il paraît que cela fonctionne, même si l’on n’y croit pas ».pdf
# Processing file: Dette, d_ficits publics_ l'id_e d'assouplir les r_gles europ_ennes gagne du terrain.pdf
# File processed: Dette, d_ficits publics_ l'id_e d'assouplir les r_gles europ_ennes gagne du terrain.pdf
# Processing file: Dette, pouvoir d'achat, inflation... Les chiffres marquants du budget 2021.pdf
# File processed: Dette, pouvoir d'achat, inflation... Les chiffres marquants du budget 2021.pdf
# Processing file: Dette, _cologie, inflation, pouvoir d'achat... En finir avec les bobards.pdf
# File processed: Dette, _cologie, inflation, pouvoir d'achat... En finir avec les bobards.pdf
# Processing file: Dettes publiques _ le FMI plaide pour des r_formes urgentes.pdf
# File processed: Dettes publiques _ le FMI plaide pour des r_formes urgentes.pdf
# Processing file: Dette_ des _lus LREM pour un d_bat _lucide et responsable_.pdf
# File processed: Dette_ des _lus LREM pour un d_bat _lucide et responsable_.pdf
# Processing file: Deux plans d'investissements, une _lection_ nouvelle semaine difficile pour Biden.pdf
# File processed: Deux plans d'investissements, une _lection_ nouvelle semaine difficile pour Biden.pdf
# Processing file: Didier Deschamps pr_sident... ou meilleur DRH de France !.pdf
# File processed: Didier Deschamps pr_sident... ou meilleur DRH de France !.pdf
# Processing file: DIRECT - Le bilan passe _ 22.245 morts en France , 389 d_c_s suppl_mentaires en 24 heures.pdf
# File processed: DIRECT - Le bilan passe _ 22.245 morts en France , 389 d_c_s suppl_mentaires en 24 heures.pdf
# Processing file: Discours de Fran_ois HOLLANDE lors du colloque _ La Gauche et le pouvoir _.pdf
# File processed: Discours de Fran_ois HOLLANDE lors du colloque _ La Gauche et le pouvoir _.pdf
# Processing file: Discours _ Caen.pdf
# File processed: Discours _ Caen.pdf
# Processing file: Diversification des cha_nes d'approvisionnement_ un m_canisme du G7 lanc_ d'ici fin 2023.pdf
# File processed: Diversification des cha_nes d'approvisionnement_ un m_canisme du G7 lanc_ d'ici fin 2023.pdf
# Processing file: Diviser par deux les _missions de gaz _ effet de serre d'ici _ 2030 La premi_re ministre _lisabeth B.pdf
# File processed: Diviser par deux les _missions de gaz _ effet de serre d'ici _ 2030 La premi_re ministre _lisabeth B.pdf
# Processing file: Dix ans apr_s, la plan_te finance toujours en surchauffe.pdf
# File processed: Dix ans apr_s, la plan_te finance toujours en surchauffe.pdf
# Processing file: Dominique Reyni__ _Aux europ_ennes, il faut s'attendre _ une nouvelle pouss_e populiste_.pdf
# File processed: Dominique Reyni__ _Aux europ_ennes, il faut s'attendre _ une nouvelle pouss_e populiste_.pdf
# Processing file: Douze propositions vertes pour une solution socialement juste et environnementalement durable _ la c.pdf
# File processed: Douze propositions vertes pour une solution socialement juste et environnementalement durable _ la c.pdf
# Processing file: Droit dans le mur de la dette.pdf
# File processed: Droit dans le mur de la dette.pdf
# Processing file: D_bat sur la dette.pdf
# File processed: D_bat sur la dette.pdf
# Processing file: D_but du marathon budg_taire _ l'Assembl_e, baisses d'imp_ts post-_gilets jaunes_ au menu.pdf
# File processed: D_but du marathon budg_taire _ l'Assembl_e, baisses d'imp_ts post-_gilets jaunes_ au menu.pdf
# Processing file: D_carboner l'_conomie fran_aise, un lourd fardeau pour les finances publiques, selon un rapport.pdf
# File processed: D_carboner l'_conomie fran_aise, un lourd fardeau pour les finances publiques, selon un rapport.pdf
# Processing file: D_carboner l'_conomie va ralentir la croissance et alourdir la dette publique, alerte France Strat_g.pdf
# File processed: D_carboner l'_conomie va ralentir la croissance et alourdir la dette publique, alerte France Strat_g.pdf
# Processing file: D_confinement_ d_partement rouge, orange ou vert_ La carte provisoire d_voil_e.pdf
# File processed: D_confinement_ d_partement rouge, orange ou vert_ La carte provisoire d_voil_e.pdf
# Processing file: D_ficit budg_taire _ dramatisation, pi_ge _ Macron.pdf
# File processed: D_ficit budg_taire _ dramatisation, pi_ge _ Macron.pdf
# Processing file: D_gradation de la note fran_aise _ faut-il s'inqui_ter du niveau de la dette _.pdf
# File processed: D_gradation de la note fran_aise _ faut-il s'inqui_ter du niveau de la dette _.pdf
# Processing file: D_penser n'est pas relancer.pdf
# File processed: D_penser n'est pas relancer.pdf
# Processing file: D_penses publiques et mesures d'_conomies_ le gouvernement sur la d_fensive.pdf
# File processed: D_penses publiques et mesures d'_conomies_ le gouvernement sur la d_fensive.pdf
# Processing file: D_penses publiques_ l inspection g_n_rale des finances identifie 2,5 milliards d euros d'_conomie.pdf
# File processed: D_penses publiques_ l inspection g_n_rale des finances identifie 2,5 milliards d euros d'_conomie.pdf
# Processing file: D_penses publiques_ l'Etat identifie 2,5 milliards d'euros d'_exc_dent_ de tr_sorerie chez ses op_ra.pdf
# File processed: D_penses publiques_ l'Etat identifie 2,5 milliards d'euros d'_exc_dent_ de tr_sorerie chez ses op_ra.pdf
# Processing file: Dépenses publiques il faut « réactiver le lien entre banque centrale et Trésor public ».pdf
# File processed: Dépenses publiques il faut « réactiver le lien entre banque centrale et Trésor public ».pdf
# Processing file: Ecologie, budget 2024, harc_lement... les infos _ suivre cette semaine.pdf
# File processed: Ecologie, budget 2024, harc_lement... les infos _ suivre cette semaine.pdf
# Processing file: Edouard Philippe _sonne l'alerte_ sur la dette publique.pdf
# File processed: Edouard Philippe _sonne l'alerte_ sur la dette publique.pdf
# Processing file: Emmanuel Macron-Marine Le Pen_ le match des projets _conomiques.pdf
# File processed: Emmanuel Macron-Marine Le Pen_ le match des projets _conomiques.pdf
# Processing file: En 2019, l'obsession budg_taire pr_vaut toujours sur les enjeux climatiques.pdf
# File processed: En 2019, l'obsession budg_taire pr_vaut toujours sur les enjeux climatiques.pdf
# Processing file: En attendant la r_cession qui ne vient pas, voyons la vie en rose !.pdf
# File processed: En attendant la r_cession qui ne vient pas, voyons la vie en rose !.pdf
# Processing file: En couverture - L'intrigant monsieur Attal Interview Xavier Jaravel _ _ Investir dans l'_ducation, c.pdf
# File processed: En couverture - L'intrigant monsieur Attal Interview Xavier Jaravel _ _ Investir dans l'_ducation, c.pdf
# Processing file: En couverture Alerte sur les d_penses publiques IMPASSE Le pi_ge du _ quoi qu'il en co_te _.pdf
# File processed: En couverture Alerte sur les d_penses publiques IMPASSE Le pi_ge du _ quoi qu'il en co_te _.pdf
# Processing file: En couverture Le pr_sident - La derni_re chance - _ Wording _, comme on dit en Macronie Les mots du.pdf
# File processed: En couverture Le pr_sident - La derni_re chance - _ Wording _, comme on dit en Macronie Les mots du.pdf
# Processing file: En couverture Le pr_sident - La derni_re chance Ne pas tomber dans le pi_ge de l'immobilisme.pdf
# File processed: En couverture Le pr_sident - La derni_re chance Ne pas tomber dans le pi_ge de l'immobilisme.pdf
# Processing file: En couverture Les boomers ont-ils ruin_ la France _ GRAND ENTRETIEN Fran_ois de Closets _ _ Les boom.pdf
# File processed: En couverture Les boomers ont-ils ruin_ la France _ GRAND ENTRETIEN Fran_ois de Closets _ _ Les boom.pdf
# Processing file: EN COUVERTURE Mondialisation ENTRETIEN [Nicolas Baverez] _ Le proc_s fait _ la mondialisation est ab.pdf
# File processed: EN COUVERTURE Mondialisation ENTRETIEN [Nicolas Baverez] _ Le proc_s fait _ la mondialisation est ab.pdf
# Processing file: EN DIRECT - La dette publique va atteindre pr_s de 121% du PIB, selon Bercy.pdf
# File processed: EN DIRECT - La dette publique va atteindre pr_s de 121% du PIB, selon Bercy.pdf
# Processing file: EN DIRECT. Coronavirus _ le gouvernement pr_voit une chute de 6 % du PIB.pdf
# File processed: EN DIRECT. Coronavirus _ le gouvernement pr_voit une chute de 6 % du PIB.pdf
# Processing file: En Italie, un parfum de renaissance.pdf
# File processed: En Italie, un parfum de renaissance.pdf
# Processing file: En Nouvelle-Z_lande, l'_conomie souffre _ la veille d'_lections.pdf
# File processed: En Nouvelle-Z_lande, l'_conomie souffre _ la veille d'_lections.pdf
# Processing file: Entretien exclusif - Thomas Piketty _ _ Historiquement, c'est le combat pour l'_galit_ qui a permis.pdf
# File processed: Entretien exclusif - Thomas Piketty _ _ Historiquement, c'est le combat pour l'_galit_ qui a permis.pdf
# Processing file: ENTRETIEN Jean Tirole _ _ La France court le risque de d_classement _.pdf
# File processed: ENTRETIEN Jean Tirole _ _ La France court le risque de d_classement _.pdf
# Processing file: Entretien _ En France , le budget est devenu une addition de strates _.pdf
# File processed: Entretien _ En France , le budget est devenu une addition de strates _.pdf
# Processing file: Eparpill_ fa_on puzzle, le Macron _.pdf
# File processed: Eparpill_ fa_on puzzle, le Macron _.pdf
# Processing file: Eric Monnet, Prix du meilleur jeune économiste 2022 « La capacité de l’Etat à agir sur l’économie n’est pas proportionnelle à ses dépenses ».pdf
# File processed: Eric Monnet, Prix du meilleur jeune économiste 2022 « La capacité de l’Etat à agir sur l’économie n’est pas proportionnelle à ses dépenses ».pdf
# Processing file: Et la Covid accoucha... du commissariat au plan.pdf
# File processed: Et la Covid accoucha... du commissariat au plan.pdf
# Processing file: Et si le d_ficit n'_tait pas un souci _ Entretien avec la cheffe de file de la _ Th_orie moderne de.pdf
# File processed: Et si le d_ficit n'_tait pas un souci _ Entretien avec la cheffe de file de la _ Th_orie moderne de.pdf
# Processing file: Et si on applaudissait aussi les banques _.pdf
# File processed: Et si on applaudissait aussi les banques _.pdf
# Processing file: Etats-Unis_ Le chef de la majorit_ d_mocrate au S_nat annonce un accord sur la dette.pdf
# File processed: Etats-Unis_ Le chef de la majorit_ d_mocrate au S_nat annonce un accord sur la dette.pdf
# Processing file: Etats-Unis_ les Cassandre de la dette s'_poumonent _ tort.pdf
# File processed: Etats-Unis_ les Cassandre de la dette s'_poumonent _ tort.pdf
# Processing file: Etats-Unis_ Un revers sur les r_formes d_cevrait les d_mocrates, dit la Maison blanche.pdf
# File processed: Etats-Unis_ Un revers sur les r_formes d_cevrait les d_mocrates, dit la Maison blanche.pdf
# Processing file: Etienne Gernelle - Que p_se le parti de la b_tise _.pdf
# File processed: Etienne Gernelle - Que p_se le parti de la b_tise _.pdf
# Processing file: Europe _ Aubry fait programme commun avec les Allemands.pdf
# File processed: Europe _ Aubry fait programme commun avec les Allemands.pdf
# Processing file: Europe _ et si le _plan B_, c'_tait l'Union m_diterran_enne _.pdf
# File processed: Europe _ et si le _plan B_, c'_tait l'Union m_diterran_enne _.pdf
# Processing file: EXCLUSIF. Inflation, climat, fiscalit_... Les v_rit_s de Tirole et Blanchard.pdf
# File processed: EXCLUSIF. Inflation, climat, fiscalit_... Les v_rit_s de Tirole et Blanchard.pdf
# Processing file: Exclusif_UE_ Rencontre entre Le Maire et son homologue allemand sur les r_gles budg_taires, selon de.pdf
# File processed: Exclusif_UE_ Rencontre entre Le Maire et son homologue allemand sur les r_gles budg_taires, selon de.pdf
# Processing file: Face aux d_put_s, Jean Castex d_taille le casse-t_te de la relance.pdf
# File processed: Face aux d_put_s, Jean Castex d_taille le casse-t_te de la relance.pdf
# Processing file: Face _ la r_cession, relancer vite... mais pas quoi qu'il en co_te.pdf
# File processed: Face _ la r_cession, relancer vite... mais pas quoi qu'il en co_te.pdf
# Processing file: Faut-il annuler la dette publique _.pdf
# File processed: Faut-il annuler la dette publique _.pdf
# Processing file: Faut-il effacer les dettes publiques li_es au Covid-19 _ OUI _ LES RISQUES D'UNE TELLE STRAT_GIE SON.pdf
# File processed: Faut-il effacer les dettes publiques li_es au Covid-19 _ OUI _ LES RISQUES D'UNE TELLE STRAT_GIE SON.pdf
# Processing file: Faut-il relancer l'_conomie par la dette publique _.pdf
# File processed: Faut-il relancer l'_conomie par la dette publique _.pdf
# Processing file: Faut-il r_tablir l'imp_t de solidarit_ sur la fortune face _ la crise sanitaire_.pdf
# File processed: Faut-il r_tablir l'imp_t de solidarit_ sur la fortune face _ la crise sanitaire_.pdf
# Processing file: Faut-il s'inqui_ter de la dette Covid _.pdf
# File processed: Faut-il s'inqui_ter de la dette Covid _.pdf
# Processing file: Faut-il sortir de l'id_ologie pour agir _ _ mesure que l'urgence _cologique se concr_tise, la soci_t.pdf
# File processed: Faut-il sortir de l'id_ologie pour agir _ _ mesure que l'urgence _cologique se concr_tise, la soci_t.pdf
# Processing file: Finance et nucl_aire _ l'impasse _.pdf
# File processed: Finance et nucl_aire _ l'impasse _.pdf
# Processing file: Financement vert _ les fausses promesses du fl_chage de l _pargne des Fran_ais.pdf
# File processed: Financement vert _ les fausses promesses du fl_chage de l _pargne des Fran_ais.pdf
# Processing file: Finances publiques _ l'optimisme du gouvernement n'est pas partag_.pdf
# File processed: Finances publiques _ l'optimisme du gouvernement n'est pas partag_.pdf
# Processing file: Finances publiques _ un scandale fran_ais !.pdf
# File processed: Finances publiques _ un scandale fran_ais !.pdf
# Processing file: Finances publiques_ le gouvernement engage un tour de vis suppl_mentaire pour le budget 2023.pdf
# File processed: Finances publiques_ le gouvernement engage un tour de vis suppl_mentaire pour le budget 2023.pdf
# Processing file: Finances publiques_ les neuf recettes de la Cour des comptes pour d_penser _moins et mieux_.pdf
# File processed: Finances publiques_ les neuf recettes de la Cour des comptes pour d_penser _moins et mieux_.pdf
# Processing file: Fiscalit_, social, finances publiques... les points-cl_s des r_formes Macron.pdf
# File processed: Fiscalit_, social, finances publiques... les points-cl_s des r_formes Macron.pdf
# Processing file: FOCUS La BCE exclut l'annulation des dettes publiques.pdf
# File processed: FOCUS La BCE exclut l'annulation des dettes publiques.pdf
# Processing file: FOG - Mais qui a cass_ le nucl_aire fran_ais _.pdf
# File processed: FOG - Mais qui a cass_ le nucl_aire fran_ais _.pdf
# Processing file: FONCTION PUBLIQUE Ces 10 d_partements qui m_riteraient un r_gime.pdf
# File processed: FONCTION PUBLIQUE Ces 10 d_partements qui m_riteraient un r_gime.pdf
# Processing file: FORUM. Le pape Fran_ois danse avec les loups. G_rard Thoris, professeur _ Sciences-Po.pdf
# File processed: FORUM. Le pape Fran_ois danse avec les loups. G_rard Thoris, professeur _ Sciences-Po.pdf
# Processing file: France -Allemagne _ quand la _ locomotive _ d_raille.pdf
# File processed: France -Allemagne _ quand la _ locomotive _ d_raille.pdf
# Processing file: France 2023 _ chute ou modernisation _.pdf
# File processed: France 2023 _ chute ou modernisation _.pdf
# Processing file: France Relance, un plan de 100 milliards d'euros pour _viter le d_crochage _conomique.pdf
# File processed: France Relance, un plan de 100 milliards d'euros pour _viter le d_crochage _conomique.pdf
# Processing file: France _ L'exercice de l'Etat [Chronique] Comment gouverner sans _tre bloqu_.pdf
# File processed: France _ L'exercice de l'Etat [Chronique] Comment gouverner sans _tre bloqu_.pdf
# Processing file: France _ le gouvernement d_voile vendredi sa recette budg_taire pour 2020.pdf
# File processed: France _ le gouvernement d_voile vendredi sa recette budg_taire pour 2020.pdf
# Processing file: France _ le gouvernement joue les _quilibristes pour le budget 2024.pdf
# File processed: France _ le gouvernement joue les _quilibristes pour le budget 2024.pdf
# Processing file: France _ les quatre chiffres-cl_ du projet de budget 2020.pdf
# File processed: France _ les quatre chiffres-cl_ du projet de budget 2020.pdf
# Processing file: France _ pour fin 2023, Bercy maintient ses pr_visions et ajuste son budget.pdf
# File processed: France _ pour fin 2023, Bercy maintient ses pr_visions et ajuste son budget.pdf
# Processing file: France_ le sc_nario macro_conomique de la France maintenu pour fin 2023.pdf
# File processed: France_ le sc_nario macro_conomique de la France maintenu pour fin 2023.pdf
# Processing file: Fran_ois Fillon plaide pour la r_novation de la gouvernance de la zone euro.pdf
# File processed: Fran_ois Fillon plaide pour la r_novation de la gouvernance de la zone euro.pdf
# ...
# Processing file: Le FMI pr_voit que la croissance mondiale sera l_g_rement inf_rieure _ sa pr_vision en 2021.pdf
# File processed: Le FMI pr_voit que la croissance mondiale sera l_g_rement inf_rieure _ sa pr_vision en 2021.pdf
# Processing file: Le FMI tire la sonnette d alarme pour juguler l ins_curit_ alimentaire _ pr_s d un milliard de perso.pdf
# File processed: Le FMI tire la sonnette d alarme pour juguler l ins_curit_ alimentaire _ pr_s d un milliard de perso.pdf
# Processing file: Le Forum _conomique mondial plaide en faveur d'_conomies _plus productives, durables et inclusives_.pdf
# File processed: Le Forum _conomique mondial plaide en faveur d'_conomies _plus productives, durables et inclusives_.pdf
# Processing file: Le G8 , le G0 et l'Am_rique.pdf
# File processed: Le G8 , le G0 et l'Am_rique.pdf
# Processing file: Le gouvernement d_voile son plan d'action de r_duction des _missions de gaz _ effet de serre.pdf
# File processed: Le gouvernement d_voile son plan d'action de r_duction des _missions de gaz _ effet de serre.pdf
# Processing file: Le gouvernement fran_ais d_ploie un nouveau budget en soutien aux secteurs fragilis_s.pdf
# File processed: Le gouvernement fran_ais d_ploie un nouveau budget en soutien aux secteurs fragilis_s.pdf
# Processing file: Le gouvernement promet d'associer LR _ des _ r_formes structurelles pour faire des _conomies _.pdf
# File processed: Le gouvernement promet d'associer LR _ des _ r_formes structurelles pour faire des _conomies _.pdf
# Processing file: Le gouvernement revoit bien le d_ficit public _ la baisse.pdf
# File processed: Le gouvernement revoit bien le d_ficit public _ la baisse.pdf
# Processing file: Le gouvernement veut revoir les concessions autorouti_res.pdf
# File processed: Le gouvernement veut revoir les concessions autorouti_res.pdf
# Processing file: Le gouvernement _plus pr_occup_ par la dette publique_ qu'__cologique_ (Lambert, LREM).pdf
# File processed: Le gouvernement _plus pr_occup_ par la dette publique_ qu'__cologique_ (Lambert, LREM).pdf
# Processing file: Le Grand d_bat national, une occasion de changer de voie.pdf
# File processed: Le Grand d_bat national, une occasion de changer de voie.pdf
# Processing file: Le Japon face aux d_fis de l'_re Reiwa.pdf
# File processed: Le Japon face aux d_fis de l'_re Reiwa.pdf
# Processing file: Le macronisme est-il soluble dans le n_olib_ralisme _.pdf
# File processed: Le macronisme est-il soluble dans le n_olib_ralisme _.pdf
# Processing file: Le manifeste des _Atterr_s_.pdf
# File processed: Le manifeste des _Atterr_s_.pdf
# Processing file: Le Medef met la libert_ au programme de la prochaine campagne pr_sidentielle.pdf
# File processed: Le Medef met la libert_ au programme de la prochaine campagne pr_sidentielle.pdf
# Processing file: Le Medef veut all_ger la fiscalit_ des entreprises pour prot_ger le climat.pdf
# File processed: Le Medef veut all_ger la fiscalit_ des entreprises pour prot_ger le climat.pdf
# Processing file: Le monde d’après « Le risque est de mettre des rustines là où il faudrait réformer en profondeur ».pdf
# File processed: Le monde d’après « Le risque est de mettre des rustines là où il faudrait réformer en profondeur ».pdf
# Processing file: Le mur de l'inflation.pdf
# File processed: Le mur de l'inflation.pdf
# Processing file: Le noeud gordien de la dette de la SNCF.pdf
# File processed: Le noeud gordien de la dette de la SNCF.pdf
# Processing file: Le nouvelle chef du FMI appelle l'Afrique _ une gestion raisonnable de la dette.pdf
# File processed: Le nouvelle chef du FMI appelle l'Afrique _ une gestion raisonnable de la dette.pdf
# Processing file: Le partenariat UE-Afrique et la pand_mie de la Covid.pdf
# File processed: Le partenariat UE-Afrique et la pand_mie de la Covid.pdf
# Processing file: Le pi_ge de la dette se referme sur la France.pdf
# File processed: Le pi_ge de la dette se referme sur la France.pdf
# Processing file: Le pi_ge de la dette... et sa solution.pdf
# File processed: Le pi_ge de la dette... et sa solution.pdf
# Processing file: Le plan Biden pour reb_tir l'Am_rique.pdf
# File processed: Le plan Biden pour reb_tir l'Am_rique.pdf
# Processing file: Le plan de relance am_ricain progresse un peu plus vite que pr_vu.pdf
# File processed: Le plan de relance am_ricain progresse un peu plus vite que pr_vu.pdf
# Processing file: Le plan sur les infrastructures adopt_ au Congr_s, Biden arrache un succ_s.pdf
# File processed: Le plan sur les infrastructures adopt_ au Congr_s, Biden arrache un succ_s.pdf
# Processing file: LE POINT DE L'ACTUALITE A 04H45 (02H45 GMT).pdf
# File processed: LE POINT DE L'ACTUALITE A 04H45 (02H45 GMT).pdf
# Processing file: Le programme de travail du FMI vise _ impulser la croissance mondiale et g_rer les risques nouveaux.pdf
# File processed: Le programme de travail du FMI vise _ impulser la croissance mondiale et g_rer les risques nouveaux.pdf
# Processing file: Le programme _conomique de la Nupes est-il vraiment s_rieux _.pdf
# File processed: Le programme _conomique de la Nupes est-il vraiment s_rieux _.pdf
# Processing file: LE PROGR_S NE S'ARR_TERA PAS EN 2019.pdf
# File processed: LE PROGR_S NE S'ARR_TERA PAS EN 2019.pdf
# Processing file: Le projet de budget 2020 sous le feu des critiques de l'opposition et du patronat.pdf
# File processed: Le projet de budget 2020 sous le feu des critiques de l'opposition et du patronat.pdf
# Processing file: Le projet de budget 2020 sous le feu des critiques.pdf
# File processed: Le projet de budget 2020 sous le feu des critiques.pdf
# Processing file: Le pr_sident de la Banque mondiale David Malpass annonce sa d_mission prochaine.pdf
# File processed: Le pr_sident de la Banque mondiale David Malpass annonce sa d_mission prochaine.pdf
# Processing file: Le rapport d'orientation budg_taire contest_.pdf
# File processed: Le rapport d'orientation budg_taire contest_.pdf
# Processing file: Le rassemblement du Centre peut _tre une vraie chance pour l'_cologie.pdf
# File processed: Le rassemblement du Centre peut _tre une vraie chance pour l'_cologie.pdf
# Processing file: Le regard de l'Europe doit se tourner vers l'Afrique.pdf
# File processed: Le regard de l'Europe doit se tourner vers l'Afrique.pdf
# Processing file: Le resserrement mon_taire de la BCE, une mauvaise nouvelle pour les _ cigales _ europ_ennes.pdf
# File processed: Le resserrement mon_taire de la BCE, une mauvaise nouvelle pour les _ cigales _ europ_ennes.pdf
# Processing file: Le retour de la croissance r_duit un peu le poids de la dette fran_aise et du d_ficit en 2021.pdf
# File processed: Le retour de la croissance r_duit un peu le poids de la dette fran_aise et du d_ficit en 2021.pdf
# Processing file: Le Royaume-Uni d_finit ses nouvelles priorit_s strat_giques Le gouvernement britannique a d_cid_ d a.pdf
# File processed: Le Royaume-Uni d_finit ses nouvelles priorit_s strat_giques Le gouvernement britannique a d_cid_ d a.pdf
# Processing file: Le spectre d'_ une r_cession mondiale _ grandit en 2023, selon la Banque mondiale.pdf
# File processed: Le spectre d'_ une r_cession mondiale _ grandit en 2023, selon la Banque mondiale.pdf
# Processing file: Le tabou de la comp_titivit_.pdf
# File processed: Le tabou de la comp_titivit_.pdf
# Processing file: Le vieillissement acc_l_r_ de la population menace l'_conomie mondiale.pdf
# File processed: Le vieillissement acc_l_r_ de la population menace l'_conomie mondiale.pdf
# Processing file: Le vote sur l'_norme plan social de Biden report_, un revers pour le pr_sident.pdf
# File processed: Le vote sur l'_norme plan social de Biden report_, un revers pour le pr_sident.pdf
# Processing file: Les (d_s)illusions du progr_s Apr_s le _ quoi qu'il en co_te _, le retour de la valeur travail.pdf
# File processed: Les (d_s)illusions du progr_s Apr_s le _ quoi qu'il en co_te _, le retour de la valeur travail.pdf
# Processing file: LES (D_S)ILLUSIONS DU PROGR_S Aux entreprises de jouer le jeu.pdf
# File processed: LES (D_S)ILLUSIONS DU PROGR_S Aux entreprises de jouer le jeu.pdf
# Processing file: Les 10 bonnes et mauvaises nouvelles de la transition _nerg_tique.pdf
# File processed: Les 10 bonnes et mauvaises nouvelles de la transition _nerg_tique.pdf
# Processing file: Les 10 mesures les plus embl_matiques.pdf
# File processed: Les 10 mesures les plus embl_matiques.pdf
# Processing file: Les besoins et les co_ts des emprunts souverains vont encore augmenter.pdf
# File processed: Les besoins et les co_ts des emprunts souverains vont encore augmenter.pdf
# Processing file: Les chantiers qui attendent Bruno Le Maire _ Bercy.pdf
# File processed: Les chantiers qui attendent Bruno Le Maire _ Bercy.pdf
# Processing file: Les cl_s de la croissance.pdf
# File processed: Les cl_s de la croissance.pdf
# Processing file: Les deux visages de l'Afrique.pdf
# File processed: Les deux visages de l'Afrique.pdf
# Processing file: Les dossiers chauds qui attendent l'ex_cutif.pdf
# File processed: Les dossiers chauds qui attendent l'ex_cutif.pdf
# Processing file: Les d_mocrates au Congr_s press_s d'offrir enfin une victoire _ Biden.pdf
# File processed: Les d_mocrates au Congr_s press_s d'offrir enfin une victoire _ Biden.pdf
# Processing file: Les d_mocrates handicap_s par leurs choix _conomiques.pdf
# File processed: Les d_mocrates handicap_s par leurs choix _conomiques.pdf
# Processing file: Les d_mocrates _ marche forc_e pour passer au Congr_s les grands plans de Biden.pdf
# File processed: Les d_mocrates _ marche forc_e pour passer au Congr_s les grands plans de Biden.pdf
# Processing file: Les d_penses face _ l'inflation doivent rester _temporaires_, alerte le gouverneur de la Banque de F.pdf
# File processed: Les d_penses face _ l'inflation doivent rester _temporaires_, alerte le gouverneur de la Banque de F.pdf
# Processing file: Les enjeux de la pr_sidence fran_aise de l'Union.pdf
# File processed: Les enjeux de la pr_sidence fran_aise de l'Union.pdf
# Processing file: Les essentiels _conomie.pdf
# File processed: Les essentiels _conomie.pdf
# Processing file: Les exportateurs de p_trole pas encore remis du choc de 2014, selon le FMI.pdf
# File processed: Les exportateurs de p_trole pas encore remis du choc de 2014, selon le FMI.pdf
# Processing file: Les finances de la France sont pass_es au tamis de la transition _cologique.pdf
# File processed: Les finances de la France sont pass_es au tamis de la transition _cologique.pdf
# Processing file: Les finances portugaises se portent _ merveille, Moody s rel_ve fortement sa note.pdf
# File processed: Les finances portugaises se portent _ merveille, Moody s rel_ve fortement sa note.pdf
# Processing file: Les finances publiques Jusqu'au second tour, _La Croix_ compare les programmes des deux finalistes s.pdf
# File processed: Les finances publiques Jusqu'au second tour, _La Croix_ compare les programmes des deux finalistes s.pdf
# Processing file: Les Fran_ais sont-ils accros _ la d_pense publique _ Le projet de budget 2024 doit _tre examin_ _ pa.pdf
# File processed: Les Fran_ais sont-ils accros _ la d_pense publique _ Le projet de budget 2024 doit _tre examin_ _ pa.pdf
# Processing file: Les gagnants et les perdants des _lections de mi-mandat aux Etats-Unis.pdf
# File processed: Les gagnants et les perdants des _lections de mi-mandat aux Etats-Unis.pdf
# Processing file: Les grands oublis du grand d_bat.pdf
# File processed: Les grands oublis du grand d_bat.pdf
# Processing file: Les patrons face aux d_fis g_opolitiques et _cologiques.pdf
# File processed: Les patrons face aux d_fis g_opolitiques et _cologiques.pdf
# Processing file: Les plus riches devront-ils financer la facture colossale de la transition _cologique _.pdf
# File processed: Les plus riches devront-ils financer la facture colossale de la transition _cologique _.pdf
# Processing file: Les principaux chantiers _conomiques du deuxi_me quinquennat Macron.pdf
# File processed: Les principaux chantiers _conomiques du deuxi_me quinquennat Macron.pdf
# Processing file: Les r_volutions en cha_ne du Covid-19.pdf
# File processed: Les r_volutions en cha_ne du Covid-19.pdf
# Processing file: Les Seychelles cr_ent une vaste r_serve maritime.pdf
# File processed: Les Seychelles cr_ent une vaste r_serve maritime.pdf
# Processing file: Les taux d'emprunt de la France s'envolent.pdf
# File processed: Les taux d'emprunt de la France s'envolent.pdf
# Processing file: Les taux n_gatifs ne doivent pas devenir une _drogue_, juge Le Maire.pdf
# File processed: Les taux n_gatifs ne doivent pas devenir une _drogue_, juge Le Maire.pdf
# Processing file: Les trois priorit_s de Macron_ le travail, l'investissement, la dette.pdf
# File processed: Les trois priorit_s de Macron_ le travail, l'investissement, la dette.pdf
# Processing file: Les troupes chinoises ne remplaceront pas les Indiens, assure le pr_sident des Maldives.pdf
# File processed: Les troupes chinoises ne remplaceront pas les Indiens, assure le pr_sident des Maldives.pdf
# Processing file: Les _conomistes au chevet de l'_conomie post-Covid.pdf
# File processed: Les _conomistes au chevet de l'_conomie post-Covid.pdf
# Processing file: Les _lus locaux inquiets d'un nouveau tour de vis financier.pdf
# File processed: Les _lus locaux inquiets d'un nouveau tour de vis financier.pdf
# Processing file: Les _l_ments _ retenir du projet de budget 2020.pdf
# File processed: Les _l_ments _ retenir du projet de budget 2020.pdf
# Processing file: Les _tats doivent _ la fois r_duire leur dette et investir.pdf
# File processed: Les _tats doivent _ la fois r_duire leur dette et investir.pdf
# Processing file: Lessentiel du programme de Jean-Luc M_lenchon.pdf
# File processed: Lessentiel du programme de Jean-Luc M_lenchon.pdf
# Processing file: Lessentiel du programme _conomique et social de Jean-Luc M_lenchon.pdf
# File processed: Lessentiel du programme _conomique et social de Jean-Luc M_lenchon.pdf
# Processing file: Lignes 17 et 18 _ les _valuations plus que discutables de la Soci_t_ du Grand Paris.pdf
# File processed: Lignes 17 et 18 _ les _valuations plus que discutables de la Soci_t_ du Grand Paris.pdf
# Processing file: Ligot_ par les experts, le discours moral et le droit, l'art de gouverner est en p_ril.pdf
# File processed: Ligot_ par les experts, le discours moral et le droit, l'art de gouverner est en p_ril.pdf
# Processing file: Limitation des d_penses et r_forme de la gouvernance budg_taire_ les recettes de la commission Arthu.pdf
# File processed: Limitation des d_penses et r_forme de la gouvernance budg_taire_ les recettes de la commission Arthu.pdf
# Processing file: Loi sur le pouvoir d'achat _ Bruno Le Maire rappelle _ l'opposition _ l'imp_ratif de r_duire l'endet.pdf
# File processed: Loi sur le pouvoir d'achat _ Bruno Le Maire rappelle _ l'opposition _ l'imp_ratif de r_duire l'endet.pdf
# Processing file: LREM _ la recherche d'une _ identit_ plus forte _.pdf
# File processed: LREM _ la recherche d'une _ identit_ plus forte _.pdf
# Processing file: LREM _ la recherche d'une _identit_ plus forte_.pdf
# File processed: LREM _ la recherche d'une _identit_ plus forte_.pdf
# Processing file: Luc Ferry_ _Comment endiguer la crise de la d_mocratie__.pdf
# File processed: Luc Ferry_ _Comment endiguer la crise de la d_mocratie__.pdf
# Processing file: Lutte d'in fluence sur le sort du patron de la Fed, Jerome Powell.pdf
# File processed: Lutte d'in fluence sur le sort du patron de la Fed, Jerome Powell.pdf
# Processing file: Lutte d'influence sur le sort du patron de la Fed, Jerome Powell.pdf
# File processed: Lutte d'influence sur le sort du patron de la Fed, Jerome Powell.pdf
# Processing file: L_gislatives en Espagne_ derri_re les pol_miques, les programmes.pdf
# File processed: L_gislatives en Espagne_ derri_re les pol_miques, les programmes.pdf
# Processing file: L_gislatives en Espagne_ les programmes des partis, derri_re les slogans.pdf
# File processed: L_gislatives en Espagne_ les programmes des partis, derri_re les slogans.pdf
# Processing file: L’annulation des dettes grecques nécessite une refondation de l’union monétaire.pdf
# File processed: L’annulation des dettes grecques nécessite une refondation de l’union monétaire.pdf
# Processing file: L’avenir de la dette Covid, un débat politique autant qu’économique.pdf

# %%
# Load the Excel document
df_fr = pd.read_excel("C:\\Users\\eugen\\corpus_article_debt\\corpus_article_debt_FR.xlsx")

# Remove " words" from the "Length" column
df_fr['Length'] = df_fr['Length'].str.replace(" words", "", regex=False)

# Continue working with df as needed without saving the modified file
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Load the Excel document
# ----> 2 df_fr = pd.read_excel("C:\\Users\\eugen\\corpus_article_debt\\corpus_article_debt_FR_1.xlsx")
#       4 # Remove " words" from the "Length" column
#       5 df_fr['Length'] = df_fr['Length'].str.replace(" words", "", regex=False)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py:457, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     455 if not isinstance(io, ExcelFile):
#     456     should_close = True
# --> 457     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     458 elif engine and engine != io.engine:
#     459     raise ValueError(
#     460         "Engine should not be specified when passing "
#     461         "an ExcelFile - ExcelFile already has the engine set"
#     462     )
#
# File ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py:1376, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1374     ext = "xls"
#    1375 else:
# -> 1376     ext = inspect_excel_format(
#    1377         content_or_path=path_or_buffer, storage_options=storage_options
#    1378     )
#    1379     if ext is None:
#    1380         raise ValueError(
#    1381             "Excel file format cannot be determined, you must specify "
#    1382             "an engine manually."
#    1383         )
#
# File ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py:1268, in inspect_excel_format(content_or_path, storage_options)
#    1265 elif not peek.startswith(ZIP_SIGNATURE):
#    1266     return None
# -> 1268 zf = zipfile.ZipFile(stream)
#    1270 # Workaround for some third party files that use forward slashes and
#    1271 # lower case names.
#    1272 component_names = [name.replace("\\", "/").lower() for name in zf.namelist()]
#
# File ~\anaconda3\lib\zipfile.py:1266, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1264 try:
#    1265     if mode == 'r':
# -> 1266         self._RealGetContents()
#    1267     elif mode in ('w', 'x'):
#    1268         # set the modified flag so central directory gets written
#    1269         # even if no files are added to the archive
#    1270         self._didModify = True
#
# File ~\anaconda3\lib\zipfile.py:1333, in ZipFile._RealGetContents(self)
#    1331     raise BadZipFile("File is not a zip file")
#    1332 if not endrec:
# -> 1333     raise BadZipFile("File is not a zip file")
#    1334 if self.debug > 1:
#    1335     print(endrec)
#
# BadZipFile: File is not a zip file

# %%
# Convert the "Date" column to datetime objects
df_fr['Date'] = pd.to_datetime(df_fr['Date'], format='%Y%m%d')

# Format the dates in the "Date" column to "YYYY/MM/DD"
df_fr['Date'] = df_fr['Date'].dt.strftime('%Y/%m/%d')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 # Convert the "Date" column to datetime objects
# ----> 2 df_fr['Date'] = pd.to_datetime(df_fr['Date'], format='%Y%m%d')
#       4 # Format the dates in the "Date" column to "YYYY/MM/DD"
#       5 df_fr['Date'] = df_fr['Date'].dt.strftime('%Y/%m/%d')
#
# NameError: name 'df_fr' is not defined

# %%
# Specify the file path
file_path = "C:\\Users\\eugen\\corpus_article_debt\\corpus_article_debt_FR.xlsx"

# Save the modified DataFrame to the same Excel file
df_fr.to_excel(file_path, index=False)
